# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\Administrator\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# !pip install numpy matplotlib seaborn
# Out:
# Requirement already satisfied: numpy in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.1.3)
# Requirement already satisfied: matplotlib in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.10.3)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\Administrator\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# PC에서 그림 설정
plt.rcParams.update({'figure.dpi' : '100'})
plt.rcParams.update({'figure.figsize' : [4,2.5]})

# %%
# PC에서 한글글 설정
plt.rcParams['axes.unicode_minus'] = False
plt.rc('font', family='Malgun Gothic')

# %%
#데이터프레임의 소수점 이하 n(2)자리 출력 설정
pd.set_option('display.precision',2)

# %%
#그림 선명하게
# %config InlineBackend.figure_format = 'retina'

# %%
pip install pyreadstat
# Out:
# Collecting pyreadstat
#   Using cached pyreadstat-1.2.8-cp311-cp311-win_amd64.whl.metadata (1.1 kB)
# Requirement already satisfied: pandas>=1.2.0 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pyreadstat) (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.2.0->pyreadstat) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.2.0->pyreadstat) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.2.0->pyreadstat) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.2.0->pyreadstat) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas>=1.2.0->pyreadstat) (1.17.0)
# Using cached pyreadstat-1.2.8-cp311-cp311-win_amd64.whl (2.4 MB)
# Installing collected packages: pyreadstat
# Successfully installed pyreadstat-1.2.8
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\Administrator\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
raw_welfare = pd.read_spss('data/koweps_hpwc14_2019_beta2.sav')
raw_welfare
# Out:
#        h14_id  h14_ind  h14_sn  h14_merkey  h_new  h14_cobf  p14_wsc  p14_wsl  \
# 0         2.0      1.0     1.0    2.01e+04    0.0       NaN     0.29     0.29
# 1         3.0      1.0     1.0    3.01e+04    0.0       NaN     0.42     0.42
# 2         4.0      1.0     1.0    4.01e+04    0.0       NaN     0.27     0.27
# 3         6.0      1.0     1.0    6.01e+04    0.0       NaN     0.49     0.50
# 4         6.0      1.0     1.0    6.01e+04    0.0       NaN     1.02     1.02
# ...       ...      ...     ...         ...    ...       ...      ...      ...
# 14413  9800.0      7.0     1.0    9.80e+07    1.0       NaN      NaN      NaN
# 14414  9800.0      7.0     1.0    9.80e+07    1.0       NaN      NaN      NaN
# 14415  9800.0      7.0     1.0    9.80e+07    1.0       NaN      NaN      NaN
# 14416  9800.0      7.0     1.0    9.80e+07    1.0       NaN      NaN      NaN
# 14417  9800.0      7.0     1.0    9.80e+07    1.0       NaN      NaN      NaN
#
#        p14_wgc  p14_wgl  ...  wc14_64  wc14_65  wc14_5aq4  wc14_5aq5  \
# 0      1307.76  1307.76  ...      NaN                 NaN        NaN
# 1      1882.57  1882.57  ...      NaN                 NaN        NaN
# 2      1189.69  1192.91  ...      NaN                 NaN        NaN
# 3      2219.63  2224.27  ...      1.0        .        2.0        4.0
# 4      4565.39  4565.39  ...      1.0        .        1.0        5.0
# ...        ...      ...  ...      ...      ...        ...        ...
# 14413      NaN      NaN  ...      NaN                 NaN        NaN
# 14414      NaN      NaN  ...      NaN                 NaN        NaN
# 14415      NaN      NaN  ...      NaN                 NaN        NaN
# 14416      NaN      NaN  ...      5.0        .        4.0        3.0
# 14417      NaN      NaN  ...      NaN                 NaN        NaN
#
#        wc14_5aq6  h14_pers_income1  h14_pers_income2  h14_pers_income3  \
# 0            NaN               NaN               NaN               NaN
# 1            NaN               NaN               NaN               NaN
# 2            NaN               NaN            1284.0               NaN
# 3            4.0            2304.0               NaN            1800.0
# 4            2.0               NaN               NaN               NaN
# ...          ...               ...               ...               ...
# 14413        NaN               NaN               NaN               NaN
# 14414        NaN               NaN               NaN               NaN
# 14415        NaN               NaN             208.0               NaN
# 14416        3.0               NaN            1200.0               NaN
# 14417        NaN               NaN               NaN               NaN
#
#        h14_pers_income4  h14_pers_income5
# 0                   0.0               NaN
# 1                   0.0               NaN
# 2                   0.0               NaN
# 3                   0.0               NaN
# 4                   0.0               NaN
# ...                 ...               ...
# 14413               0.0               NaN
# 14414               0.0               NaN
# 14415               0.0               NaN
# 14416               0.0               NaN
# 14417               0.0               NaN
#
# [14418 rows x 830 columns]

# %%
raw_welfare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14418 entries, 0 to 14417
# Columns: 830 entries, h14_id to h14_pers_income5
# dtypes: float64(826), object(4)
# memory usage: 91.3+ MB

# %%
welfare = raw_welfare.copy()

# %%
welfare.shape
# Out:
# (14418, 830)

# %%
welfare = welfare.rename(columns= {'h14_g3': 'sex',
                                   'h14_g4': 'birth',
                                   'h14_g10': 'marriage_type',
                                   'h14_g11': 'religion',
                                   'p1402_8aq1': 'income',
                                   'h14_eco0': 'code_job',
                                   'h14_reg7': 'code_region'})
welfare['sex']
# Out:
# 0        2.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        2.0
#         ...
# 14413    2.0
# 14414    2.0
# 14415    1.0
# 14416    2.0
# 14417    1.0
# Name: sex, Length: 14418, dtype: float64

# %%
welfare.sex.value_counts()
# Out:
# sex
# 2.0    7913
# 1.0    6505
# Name: count, dtype: int64

# %%
welfare.sex.isna().sum()
# Out:
# np.int64(0)

# %%
welfare['sex'] = np.where(welfare.sex == 1, 'male', 'female')
welfare['sex'].value_counts()
# Out:
# sex
# female    7913
# male      6505
# Name: count, dtype: int64

# %%
sns.countplot(welfare, x='sex', hue='sex');

# %% [markdown]
# # 11주차 수업

# %%
welfare['income'].dtypes  # 변수 타입 출력
# Out:
# dtype('float64')

# %%
welfare['income'].describe()  # 요약 통계량 구하기
# Out:
# count    4534.00
# mean      268.46
# std       198.02
# min         0.00
# 25%       150.00
# 50%       220.00
# 75%       345.75
# max      1892.00
# Name: income, dtype: float64

# %%
sns.histplot(data = welfare, x = 'income')  # 히스토그램 만들기
# Out:
# <Axes: xlabel='income', ylabel='Count'>

# %%
welfare['income'].describe()  # 이상치 확인
# Out:
# count    4534.00
# mean      268.46
# std       198.02
# min         0.00
# 25%       150.00
# 50%       220.00
# 75%       345.75
# max      1892.00
# Name: income, dtype: float64

# %%
welfare['income'].isna().sum()  # 결측치 확인
# Out:
# np.int64(9884)

# %%
# 이상치 결측 처리
welfare['income'] = np.where(welfare['income'] == 9999, np.nan, welfare['income'])

# 결측치 확인
welfare['income'].isna().sum()
# Out:
# np.int64(9884)

# %% [markdown]
# # 성별에 따른 월급 차이 분석하기

# %%
## 성별 월급 평균표 만들기

# income 결측치 제거
# sex별 분리
# income 평균 구하기
sex_income = welfare.dropna(subset = ['income']) \
                    .groupby('sex', as_index = False) \
                    .agg(mean_income = ('income', 'mean'))
sex_income
# Out:
#       sex  mean_income
# 0  female       186.29
# 1    male       349.04

# %%
# 막대 그래프 만들기
sns.barplot(data = sex_income, x = 'sex', y = 'mean_income')
# Out:
# <Axes: xlabel='sex', ylabel='mean_income'>

# %% [markdown]
# # 09-3 나이와 월급의 관계 - 몇 살 때 월급을 가장 많이 받을까?

# %%
welfare['birth'].dtypes  # 변수 타입 출력
# Out:
# dtype('float64')

# %%
welfare['birth'].describe()  # 요약 통계량 구하기
# Out:
# count    14418.00
# mean      1969.28
# std         24.40
# min       1907.00
# 25%       1948.00
# 50%       1968.00
# 75%       1990.00
# max       2018.00
# Name: birth, dtype: float64

# %%
sns.histplot(data = welfare, x = 'birth')  # 히스토그램 만들기
# Out:
# <Axes: xlabel='birth', ylabel='Count'>

# %%
welfare['birth'].describe()  # 이상치 확인
# Out:
# count    14418.00
# mean      1969.28
# std         24.40
# min       1907.00
# 25%       1948.00
# 50%       1968.00
# 75%       1990.00
# max       2018.00
# Name: birth, dtype: float64

# %%
welfare['birth'].isna().sum()  # 결측치 확인
# Out:
# np.int64(0)

# %%
# 이상치 결측 처리
welfare['birth'] = np.where(welfare['birth'] == 9999, np.nan, welfare['birth'])

# 결측치 확인
welfare['birth'].isna().sum()
# Out:
# np.int64(0)

# %%
welfare = welfare.assign(age = 2019 - welfare['birth'] + 1)  # 나이 변수 만들기
welfare['age'].describe()                                    # 요약 통계량 구하기
# Out:
# count    14418.00
# mean        50.72
# std         24.40
# min          2.00
# 25%         30.00
# 50%         52.00
# 75%         72.00
# max        113.00
# Name: age, dtype: float64

# %%
sns.histplot(data = welfare, x = 'age')  # 히스토그램 만들기
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# # 나이와 월급의 관계 분석하기

# %%
## 나이별 월급 평균표 만들기

# income 결측치 제거
# age별 분리
# income 평균 구하기
age_income = welfare.dropna(subset = ['income']) \
                    .groupby('age') \
                    .agg(mean_income = ('income', 'mean'))
age_income.head()
# Out:
#       mean_income
# age
# 19.0       162.00
# 20.0       121.33
# 21.0       136.40
# 22.0       123.67
# 23.0       179.68

# %%
# 선 그래프 만들기
sns.lineplot(data = age_income, x = 'age', y = 'mean_income')
# Out:
# <Axes: xlabel='age', ylabel='mean_income'>

# %%
# 나이 변수 살펴보기
welfare['age'].head()
# Out:
# 0    75.0
# 1    72.0
# 2    78.0
# 3    58.0
# 4    57.0
# Name: age, dtype: float64

# %%
# 연령대 변수 만들기
welfare = welfare.assign(ageg = np.where(welfare['age'] <  30, 'young',
                                np.where(welfare['age'] <= 59, 'middle', 'old')))

# 빈도 구하기
welfare['ageg'].value_counts()
# Out:
# ageg
# old       5955
# middle    4963
# young     3500
# Name: count, dtype: int64

# %%
# 빈도 막대 그래프 만들기
sns.countplot(data = welfare, x = 'ageg')
# Out:
# <Axes: xlabel='ageg', ylabel='count'>

# %%
## 연령대별 월급 평균표 만들기

# income 결측치 제거
# ageg별 분리
# income 평균 구하기
ageg_income = welfare.dropna(subset = ['income']) \
                     .groupby('ageg', as_index = False) \
                     .agg(mean_income = ('income', 'mean'))
ageg_income
# Out:
#      ageg  mean_income
# 0  middle       329.16
# 1     old       140.13
# 2   young       195.66

# %%
# 막대 그래프 만들기
sns.barplot(data = ageg_income, x = 'ageg', y = 'mean_income')
# Out:
# <Axes: xlabel='ageg', ylabel='mean_income'>

# %%
# 막대 정렬하기
sns.barplot(data = ageg_income, x = 'ageg', y = 'mean_income',
            order = ['young', 'middle', 'old'])
# Out:
# <Axes: xlabel='ageg', ylabel='mean_income'>

# %%
## 연령대 및 성별 평균표 만들기

# income 결측치 제거
# ageg 및 sex별 분리
# income 평균 구하기
sex_income = welfare.dropna(subset = ['income']) \
                    .groupby(['ageg', 'sex'], as_index = False) \
                    .agg(mean_income = ('income', 'mean'))
sex_income
# Out:
#      ageg     sex  mean_income
# 0  middle  female       230.48
# 1  middle    male       409.54
# 2     old  female        90.23
# 3     old    male       204.57
# 4   young  female       189.82
# 5   young    male       204.91

# %%
# 막대 그래프 만들기
sns.barplot(data = sex_income, x = 'ageg', y = 'mean_income', hue = 'sex',
            order = ['young', 'middle', 'old'])
# Out:
# <Axes: xlabel='ageg', ylabel='mean_income'>

# %%
## 나이 및 성별 월급 평균표 만들기

# income 결측치 제거
# age 및 sex별 분리
# income 평균 구하기
sex_age = welfare.dropna(subset = ['income']) \
                 .groupby(['age', 'sex'], as_index = False) \
                 .agg(mean_income = ('income', 'mean'))
sex_age.head()
# Out:
#     age     sex  mean_income
# 0  19.0    male       162.00
# 1  20.0  female        87.67
# 2  20.0    male       155.00
# 3  21.0  female       124.00
# 4  21.0    male       186.00

# %%
# 선 그래프 만들기
sns.lineplot(data = sex_age, x = 'age', y = 'mean_income', hue = 'sex')
# Out:
# <Axes: xlabel='age', ylabel='mean_income'>

# %%
welfare['religion'].dtypes  # 변수 타입 출력
# Out:
# dtype('float64')

# %%
welfare['religion'].value_counts()  # 빈도 구하기
# Out:
# religion
# 2.0    7815
# 1.0    6603
# Name: count, dtype: int64

# %%
# 종교 유무 이름 부여
welfare['religion'] = np.where(welfare['religion'] == 1, 'yes', 'no')

# 빈도 구하기
welfare['religion'].value_counts()
# Out:
# religion
# no     7815
# yes    6603
# Name: count, dtype: int64

# %%
# 막대 그래프 만들기
sns.countplot(data = welfare, x = 'religion')
# Out:
# <Axes: xlabel='religion', ylabel='count'>

# %%
welfare['marriage_type'].dtypes  # 변수 타입 출력
# Out:
# dtype('float64')

# %%
welfare['marriage_type'].value_counts()  # 빈도 구하기
# Out:
# marriage_type
# 1.0    7190
# 5.0    2357
# 0.0    2121
# 2.0    1954
# 3.0     689
# 4.0      78
# 6.0      29
# Name: count, dtype: int64

# %%
# 이혼 여부 변수 만들기
welfare['marriage'] = np.where(welfare['marriage_type'] == 1, 'marriage',
                      np.where(welfare['marriage_type'] == 3, 'divorce', 'etc'))

# %%
## 이혼 여부별 빈도

# marriage별 분리
# marriage별 빈도 구하기
n_divorce = welfare.groupby('marriage', as_index = False) \
                   .agg(n = ('marriage', 'count'))
n_divorce
# Out:
#    marriage     n
# 0   divorce   689
# 1       etc  6539
# 2  marriage  7190

# %%
# 막대 그래프 만들기
sns.barplot(data = n_divorce, x = 'marriage', y = 'n')
# Out:
# <Axes: xlabel='marriage', ylabel='n'>

# %%
# etc 제외
# religion별 분리
# marriage 추출
# 비율 구하기
rel_div = welfare.query('marriage != "etc"') \
                 .groupby('religion', as_index = False) \
                 ['marriage'] \
                 .value_counts(normalize = True)
rel_div
# Out:
#   religion  marriage  proportion
# 0       no  marriage        0.91
# 1       no   divorce        0.09
# 2      yes  marriage        0.92
# 3      yes   divorce        0.08

# %%
# divorce 추출
# 백분율로 바꾸기
# 반올림
rel_div = rel_div.query('marriage == "divorce"') \
                 .assign(proportion = rel_div['proportion'] * 100) \
                 .round(1)
rel_div
# Out:
#   religion marriage  proportion
# 1       no  divorce         9.5
# 3      yes  divorce         8.0

# %%
# 막대 그래프 만들기
sns.barplot(data = rel_div, x = 'religion', y = 'proportion')
# Out:
# <Axes: xlabel='religion', ylabel='proportion'>

# %%
# etc 제외, 초년층 제외
# ageg, religion별 분리
# marriage 추출
# 비율 구하기
age_rel_div = welfare.query('marriage != "etc" & ageg != "young"') \
                     .groupby(['ageg', 'religion'], as_index = False) \
                     ['marriage'] \
                     .value_counts(normalize = True)
           
age_rel_div
# Out:
#      ageg religion  marriage  proportion
# 0  middle       no  marriage        0.90
# 1  middle       no   divorce        0.10
# 2  middle      yes  marriage        0.92
# 3  middle      yes   divorce        0.08
# 4     old       no  marriage        0.90
# 5     old       no   divorce        0.10
# 6     old      yes  marriage        0.92
# 7     old      yes   divorce        0.08

# %%
# 지역 코드 목록 만들기
list_region = pd.DataFrame({'code_region' : [1, 2, 3, 4, 5, 6, 7],
                            'region'      : ['서울',
                                             '수도권(인천/경기)',
                                             '부산/경남/울산',
                                             '대구/경북',
                                             '대전/충남',
                                             '강원/충북',
                                             '광주/전남/전북/제주도']})
list_region
# Out:
#    code_region        region
# 0            1            서울
# 1            2    수도권(인천/경기)
# 2            3      부산/경남/울산
# 3            4         대구/경북
# 4            5         대전/충남
# 5            6         강원/충북
# 6            7  광주/전남/전북/제주도

# %%
# 지역명 변수 추가
welfare = welfare.merge(list_region, how = 'left', on = 'code_region')
welfare[['code_region', 'region']].head()
# Out:
#    code_region region
# 0          1.0     서울
# 1          1.0     서울
# 2          1.0     서울
# 3          1.0     서울
# 4          1.0     서울

# %%
# region별 분리
# ageg 추출
# 비율 구하기
region_ageg = welfare.groupby('region', as_index = False) \
                     ['ageg'] \
                     .value_counts(normalize = True)
region_ageg
# Out:
#           region    ageg  proportion
# 0          강원/충북     old        0.46
# 1          강원/충북  middle        0.31
# 2          강원/충북   young        0.23
# 3   광주/전남/전북/제주도     old        0.45
# 4   광주/전남/전북/제주도  middle        0.32
# 5   광주/전남/전북/제주도   young        0.23
# 6          대구/경북     old        0.50
# 7          대구/경북  middle        0.30
# 8          대구/경북   young        0.20
# 9          대전/충남     old        0.41
# 10         대전/충남  middle        0.34
# 11         대전/충남   young        0.25
# 12      부산/경남/울산     old        0.44
# 13      부산/경남/울산  middle        0.33
# 14      부산/경남/울산   young        0.23
# 15            서울  middle        0.39
# 16            서울     old        0.38
# 17            서울   young        0.24
# 18    수도권(인천/경기)  middle        0.39
# 19    수도권(인천/경기)     old        0.33
# 20    수도권(인천/경기)   young        0.29

# %% [markdown]
# ## 피벗테이블:기말시험 가능

# %%
# 피벗
pivot_df = region_ageg[['region', 'ageg', 'proportion']].pivot(index   = 'region',
                                                               columns = 'ageg',
                                                               values  = 'proportion')
pivot_df
# Out:
# ageg          middle   old  young
# region
# 강원/충북           0.31  0.46   0.23
# 광주/전남/전북/제주도    0.32  0.45   0.23
# 대구/경북           0.30  0.50   0.20
# 대전/충남           0.34  0.41   0.25
# 부산/경남/울산        0.33  0.44   0.23
# 서울              0.39  0.38   0.24
# 수도권(인천/경기)      0.39  0.33   0.29

# %%
# 막대 그래프 만들기
sns.barplot(data = region_ageg, y = 'region', x = 'proportion', hue = 'ageg')
# Out:
# <Axes: xlabel='proportion', ylabel='region'>

# %%
# 피벗
pivot_df = region_ageg[['region', 'ageg', 'proportion']].pivot(index   = 'region',
                                                               columns = 'ageg',
                                                               values  = 'proportion')
pivot_df
# Out:
# ageg          middle   old  young
# region
# 강원/충북           0.31  0.46   0.23
# 광주/전남/전북/제주도    0.32  0.45   0.23
# 대구/경북           0.30  0.50   0.20
# 대전/충남           0.34  0.41   0.25
# 부산/경남/울산        0.33  0.44   0.23
# 서울              0.39  0.38   0.24
# 수도권(인천/경기)      0.39  0.33   0.29

# %%
# 가로 막대 그래프 만들기
pivot_df.plot.barh(stacked = True)
# Out:
# <Axes: ylabel='region'>

# %%
# 노년층 비율 기준 정렬, 변수 순서 바꾸기
reorder_df = pivot_df.sort_values('old')[['young', 'middle', 'old']]
reorder_df
# Out:
# ageg          young  middle   old
# region
# 수도권(인천/경기)     0.29    0.39  0.33
# 서울             0.24    0.39  0.38
# 대전/충남          0.25    0.34  0.41
# 부산/경남/울산       0.23    0.33  0.44
# 광주/전남/전북/제주도   0.23    0.32  0.45
# 강원/충북          0.23    0.31  0.46
# 대구/경북          0.20    0.30  0.50

# %%
# 누적 가로 막대 그래프 만들기
reorder_df.plot.barh(stacked = True)
# Out:
# <Axes: ylabel='region'>

# %%
reorder_df.plot.barh()
# Out:
# <Axes: ylabel='region'>

# %% [markdown]
# ## 종료
